# %% [markdown]
# Urban Data Science & Smart Cities <br>
# URSP688Y Spring 2026<br>
# Instructor: Chester Harvey <br>
# Urban Studies & Planning <br>
# National Center for Smart Growth <br>
# University of Maryland

# %% [markdown]
# # Demo 9 - Network Analysis
#
# Today, I'm introducing network analysis with a Python package called [OSMnx](https://osmnx.readthedocs.io/en/stable/) that both downloads and analyzes street networks from OpenStreetMap (OSM). This package was written by Geoff Boeing, now at USC, while he was in grad school, a demonstration of how grad students with an interest in coding can author open-source tools with influence that stretches far beyond their own work.
#
# Beneath the hood, OSMnx relies on a network analysis package called [NetworkX](https://networkx.org/); it's one of the dominant Python tools for storing and analyzing networks, or as mathematicians tend to call them, "graphs."
#
# A network or graph, I'll use these terms interchangeably, is made up of "nodes" or "vertices"—the objects that are related to one another—and "edges" or "links"—connections that define relationships between nodes. In a street network, you can think of the nodes as intersections and the edges as street segments. You could also, however, use a graph to represent more abstract concepts, such as communities. Social network models, for example, use nodes to represent people and edges to represent relationships between them. You could imagine adding attributes to those edges to represent the strength of different relationship (e.g., strong or weak ties), just as length, speed limit, or lane counts along edges in a street network are indicators of connection between two intersections.
#
# The following graph has 6 nodes and edges making direct connections between certain pairs of nodes but not others.
#
# <img alt="basic graph" width=300 src="https://upload.wikimedia.org/wikipedia/commons/thumb/5/5b/6n-graf.svg/1920px-6n-graf.svg.png">
#
# We're going to practice analyzing a street network today in terms of shortest paths, a common type of analysis in transportation planning. Another common way of analyzing graphs is based on "degree," the number of nodes connected to a given node. A graph where all nodes are connected to each other would have high "degree centrality," while a graph where nodes are not very well-connected would have low centrality.
#
# Let's install OSMnx, which will automatically install NetworkX as a dependency.
#
# We'll first build a basic graph in NetworkX to demonstrate how it works. Then we'll use OSMnx to download an OSM street network and calculate shortest paths across it.

# %%
# Install OSMNX
# !pip install osmnx

# %%
import os
import pandas as pd
import geopandas as gpd
import osmnx as ox
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# # Build a Basic Graph
#
# Can we build the same graph pictured here in NetworkX?
#
# <img alt="basic graph" width=300 src="https://upload.wikimedia.org/wikipedia/commons/thumb/5/5b/6n-graf.svg/1920px-6n-graf.svg.png">

# %%
# Create an empty graph
G = nx.Graph()

# Add nodes to the graph
G.add_node(1)
G.add_node(2)
G.add_node(3)
G.add_node(4)
G.add_node(5)
G.add_node(6)

# Add edges between nodes
G.add_edge(1, 2)
G.add_edge(1, 5)
G.add_edge(2, 5)
G.add_edge(2, 3)
G.add_edge(3, 4)
G.add_edge(4, 5)
G.add_edge(4, 6)

# Draw the graph with labels
nx.draw(G, with_labels=True)
plt.show()

# %%
# Degrees from a given node
G.degree(1)
# Out:
# 2

# %%
# Centrality for each vertex
# (degrees / count of other nodes)
nx.degree_centrality(G)
# Out:
# {1: 0.4,
#  2: 0.6000000000000001,
#  3: 0.4,
#  4: 0.6000000000000001,
#  5: 0.6000000000000001,
#  6: 0.2}

# %%
# Average centrality
sum(nx.degree_centrality(G).values()) / len(G.nodes())
# Out:
# 0.46666666666666673

# %%
# Shortest path ---> Determined by how many nodes it needs to go through (not how difficult it might be which would be a WEIGHTED shortest path - by an attribute)
nx.shortest_path(G, 6, 1)  #Calculating paths across your networks  --> from node 6 to node 1
# Out:
# [6, 4, 5, 1]

# %%
nx.shortest_path(G, 4, 2) #Testing this one to see if the program will chose to go through node 5 or 3 since we physically do not know which one is shorter
# Out:
# [4, 5, 2]

# %% [markdown]
# # Analyzing a Street Network
#
# ## Load a street network from OSM

# %%
# Define coordinate systems
UTM18 = 26918
WGS84 = 4326

# %%
# Retrieve the street network for Washington, DC
place = 'Washington, DC, USA'
dc_network_g = ox.graph_from_place(place, network_type='drive')
dc_network_g = ox.project_graph(dc_network_g, to_crs=UTM18)
# Convert to geodataframes for easy plotting and exploration
dc_network_nodes, dc_network_edges = ox.graph_to_gdfs(dc_network_g)

# %%
ox.plot_graph(dc_network_g)
# Out:
# (<Figure size 800x800 with 1 Axes>, <Axes: >)

# %%
dc_network_nodes
# Out:
#                         y              x  street_count highway  ref junction  \
# osmid
# 49184747     4.313438e+06  318180.695053             3     NaN  NaN      NaN
# 49198976     4.313487e+06  318231.640197             3     NaN  NaN      NaN
# 937305437    4.313432e+06  318174.083723             3     NaN  NaN      NaN
# 49786378     4.313435e+06  318303.801684             4    stop  NaN      NaN
# 49190879     4.316197e+06  325259.895265             3     NaN  NaN      NaN
# ...                   ...            ...           ...     ...  ...      ...
# 13437605382  4.304897e+06  325149.549827             1     NaN  NaN      NaN
# 13437605384  4.304871e+06  325149.051349             1     NaN  NaN      NaN
# 13446783795  4.314809e+06  323441.491785             1     NaN  NaN      NaN
# 13502526528  4.310427e+06  327993.760791             1     NaN  NaN      NaN
# 13610567869  4.313261e+06  323532.331763             3     NaN  NaN      NaN
#
#                                    geometry
# osmid
# 49184747     POINT (318180.695 4313437.873)
# 49198976      POINT (318231.64 4313486.593)
# 937305437    POINT (318174.084 4313431.674)
# 49786378     POINT (318303.802 4313434.706)
# 49190879     POINT (325259.895 4316196.522)
# ...                                     ...
# 13437605382   POINT (325149.55 4304897.279)
# 13437605384  POINT (325149.051 4304870.785)
# 13446783795  POINT (323441.492 4314809.257)
# 13502526528  POINT (327993.761 4310427.166)
# 13610567869  POINT (323532.332 4313260.953)
#
# [10078 rows x 7 columns]

# %%
dc_network_nodes.plot()
# Out:
# <Axes: >

# %%
dc_network_edges.head()
# Out:
#                                            osmid      highway lanes maxspeed  \
# u        v          key
# 49184747 49198976   0                    6055425      primary     2   25 mph
#          937305437  0                  422411000      primary     2   25 mph
#          49786378   0    [1160242529, 520475705]  residential   NaN      NaN
# 49198976 49184747   0                    6055425      primary     2   25 mph
#          3900798861 0                    6055425      primary     2   25 mph
#
#                                                 name  oneway reversed  \
# u        v          key
# 49184747 49198976   0       Western Avenue Northwest   False    False
#          937305437  0       Western Avenue Northwest   False     True
#          49786378   0    Chesapeake Street Northwest   False     True
# 49198976 49184747   0       Western Avenue Northwest   False     True
#          3900798861 0       Western Avenue Northwest   False    False
#
#                              length  \
# u        v          key
# 49184747 49198976   0     70.462094
#          937305437  0      9.060611
#          49786378   0    122.846221
# 49198976 49184747   0     70.462094
#          3900798861 0     99.509709
#
#                                                                   geometry  \
# u        v          key
# 49184747 49198976   0    LINESTRING (318180.695 4313437.873, 318231.64 ...
#          937305437  0    LINESTRING (318180.695 4313437.873, 318178.078...
#          49786378   0    LINESTRING (318180.695 4313437.873, 318192.957...
# 49198976 49184747   0    LINESTRING (318231.64 4313486.593, 318180.695 ...
#          3900798861 0    LINESTRING (318231.64 4313486.593, 318246.705 ...
#
#                          ref bridge junction tunnel width access
# u        v          key
# 49184747 49198976   0    NaN    NaN      NaN    NaN   NaN    NaN
#          937305437  0    NaN    NaN      NaN    NaN   NaN    NaN
#          49786378   0    NaN    NaN      NaN    NaN   NaN    NaN
# 49198976 49184747   0    NaN    NaN      NaN    NaN   NaN    NaN
#          3900798861 0    NaN    NaN      NaN    NaN   NaN    NaN

# %%
dc_network_edges.plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Load other data

# %%
# Load affordable housing points
affordable_housing = gpd.read_file('Affordable_Housing.geojson').to_crs(UTM18)

# %%
affordable_housing.plot()
# Out:
# <Axes: >

# %%
# Load Metro Center point
metro_center = gpd.points_from_xy([-77.032774], [38.8985198])
metro_center = gpd.GeoDataFrame(geometry=metro_center, crs=WGS84).to_crs(epsg=UTM18)

# %%
# Map data to make sure everything lines up
ax = dc_network_edges.plot(color='black', zorder=1)
affordable_housing.plot(ax=ax, color='blue', zorder=2)
metro_center.plot(ax=ax, color='red', zorder=3)
# Out:
# <Axes: >

# %% [markdown]
# ## Relate points to street network

# %%
# Find the nearest node to metro center
metro_center_nodes, metro_center_node_dists = ox.nearest_nodes(
    dc_network_g,
    metro_center.geometry.get_coordinates().x, 
    metro_center.geometry.get_coordinates().y, 
    return_dist=True)

# %%
metro_center_nodes
# Out:
# array([49745629])

# %%
dc_network_nodes.loc[49745629]
# Out:
# y                                            4307456.017836
# x                                             323789.795446
# street_count                                              4
# highway                                     traffic_signals
# ref                                                     NaN
# junction                                                NaN
# geometry        POINT (323789.7954457104 4307456.017836036)
# Name: 49745629, dtype: object

# %%
metro_center_node_dists
# Out:
# array([74.35849321])

# %%
# Find the nearest nodes to affordable housing units
affordable_housing_nodes, affordable_housing_node_dists = ox.nearest_nodes(
    dc_network_g,
    affordable_housing.geometry.get_coordinates().x,
    affordable_housing.geometry.get_coordinates().y,
    return_dist=True)

# %%
affordable_housing_nodes[:5]
# Out:
# array([  49732176,   49780064, 7930223889, 7930223077,   49884831])

# %%
#Create histogram from the class video
# affordable_housing_nodes[:5]

# %%
affordable_housing_node_dists[:5]
# Out:
# array([ 55.85755504,  35.38954561,  56.23098935, 218.00852907,
#         44.48703854])

# %% [markdown]
# ## Calculate shortest path

# %%
# Calculate shortest path between the first affordable housing project and metro center
affordable_housing_node = affordable_housing_nodes[0]
metro_center_node = metro_center_nodes[0]

route = ox.shortest_path(
    dc_network_g, 
    affordable_housing_node, 
    metro_center_node, 
    #weight='length',
)

# %%
route
# Out:
# [np.int64(49732176),
#  1488054227,
#  49726929,
#  11355443454,
#  49840959,
#  49717073,
#  49717030,
#  49775807,
#  49777288,
#  639388319,
#  49734492,
#  1439840033,
#  49751361,
#  49728917,
#  49717490,
#  49727637,
#  9093791451,
#  641912605,
#  8386386294,
#  8455863387,
#  8455846798,
#  8455863520,
#  641940023,
#  9533966093,
#  641939976,
#  3608395904,
#  5128694815,
#  641939669,
#  11198264290,
#  641939695,
#  641965151,
#  641965296,
#  641965187,
#  641965271,
#  641965070,
#  49716680,
#  49738698,
#  3000712324,
#  4951816813,
#  4951816814,
#  3010698041,
#  641964881,
#  641964879,
#  49757901,
#  49757896,
#  49764070,
#  11262878018,
#  3011273410,
#  3011273427,
#  8450945964,
#  8450945961,
#  49748170,
#  13451873036,
#  49748690,
#  3011565315,
#  3012429749,
#  3012535147,
#  3378616472,
#  3013484854,
#  3016605397,
#  3027616106,
#  3027738437,
#  3027822526,
#  3027832454,
#  49745628,
#  np.int64(49745629)]

# %%
fig, ax = ox.plot_graph_route(dc_network_g, route, route_color="y", route_linewidth=6, node_size=0)

# %% [markdown]
# ## Calculate travel time

# %%
dc_network_edges.head()
# Out:
#                                            osmid      highway lanes maxspeed  \
# u        v          key
# 49184747 49198976   0                    6055425      primary     2   25 mph
#          937305437  0                  422411000      primary     2   25 mph
#          49786378   0    [1160242529, 520475705]  residential   NaN      NaN
# 49198976 49184747   0                    6055425      primary     2   25 mph
#          3900798861 0                    6055425      primary     2   25 mph
#
#                                                 name  oneway reversed  \
# u        v          key
# 49184747 49198976   0       Western Avenue Northwest   False    False
#          937305437  0       Western Avenue Northwest   False     True
#          49786378   0    Chesapeake Street Northwest   False     True
# 49198976 49184747   0       Western Avenue Northwest   False     True
#          3900798861 0       Western Avenue Northwest   False    False
#
#                              length  speed_kph  travel_time  \
# u        v          key
# 49184747 49198976   0     70.462094  40.233500     6.304784
#          937305437  0      9.060611  40.233500     0.810722
#          49786378   0    122.846221  35.880597    12.325503
# 49198976 49184747   0     70.462094  40.233500     6.304784
#          3900798861 0     99.509709  40.233500     8.903897
#
#                                                                   geometry  \
# u        v          key
# 49184747 49198976   0    LINESTRING (318180.695 4313437.873, 318231.64 ...
#          937305437  0    LINESTRING (318180.695 4313437.873, 318178.078...
#          49786378   0    LINESTRING (318180.695 4313437.873, 318192.957...
# 49198976 49184747   0    LINESTRING (318231.64 4313486.593, 318180.695 ...
#          3900798861 0    LINESTRING (318231.64 4313486.593, 318246.705 ...
#
#                          ref bridge junction tunnel width access
# u        v          key
# 49184747 49198976   0    NaN    NaN      NaN    NaN   NaN    NaN
#          937305437  0    NaN    NaN      NaN    NaN   NaN    NaN
#          49786378   0    NaN    NaN      NaN    NaN   NaN    NaN
# 49198976 49184747   0    NaN    NaN      NaN    NaN   NaN    NaN
#          3900798861 0    NaN    NaN      NaN    NaN   NaN    NaN

# %%
# impute speed on all edges missing data
dc_network_g = ox.add_edge_speeds(dc_network_g)

# calculate travel time (seconds) for all edges
dc_network_g = ox.add_edge_travel_times(dc_network_g)

# Convert to geodataframes
dc_network_nodes, dc_network_edges = ox.graph_to_gdfs(dc_network_g)

# %%
route = ox.shortest_path(
    dc_network_g, 
    affordable_housing_node, 
    metro_center_node, 
    weight='travel_time',
)

# %%
fig, ax = ox.plot_graph_route(dc_network_g, route, route_color="y", route_linewidth=6, node_size=0)

# %%
# Add up route time
ox.routing.route_to_gdf(dc_network_g, route)["travel_time"].sum()
# Out:
# np.float64(621.0265903723666)

# %%
# Add up route length
ox.routing.route_to_gdf(dc_network_g, route)['length'].sum()
# Out:
# np.float64(9440.91047575277)

# %% [markdown]
# ## Loop calculations for bulk processing

# %%
def shortest_paths_to_metro_center(graph, o_nodes, d_node, weight='length'):    
    # Calculate shortest paths between each O-D pair
    d_nodes = [d_node] * len(o_nodes)
    routes = ox.shortest_path(graph, o_nodes, d_nodes, weight=weight)
    # Gather data for edges along each route
    combined_route_edges = []
    for route_id, route in enumerate(routes):
        route_edges = ox.routing.route_to_gdf(dc_network_g, route)
        route_edges['route_id'] = route_id
        combined_route_edges.append(route_edges)
    combined_route_edges = pd.concat(combined_route_edges, axis=0)
    # Sum length and travel time for edges involved with each route
    route_summaries = combined_route_edges.groupby('route_id')[['length','travel_time']].sum()
    # Clean up column names
    route_summaries = route_summaries.rename(columns={'length':'dist_to_metro_center', 'travel_time': 'time_to_metro_center'})
    return route_summaries
        
routes = shortest_paths_to_metro_center(
    dc_network_g, 
    affordable_housing_nodes, 
    metro_center_node, 
    weight='length'
)

routes.head()
# Out:
#           dist_to_metro_center  time_to_metro_center
# route_id
# 0                  7928.957103            686.288552
# 1                  1979.256746            169.955236
# 2                  8378.579379            731.400404
# 3                  8300.334426            724.244857
# 4                  9748.687894            801.602413

# %%
# Add distance and time estimates back to affordable housing df
affordable_housing = pd.concat([affordable_housing, routes], axis=1)

# %%
affordable_housing.head()
# Out:
#    OBJECTID MAR_WARD                                            ADDRESS  \
# 0    382721   Ward 8  2730 Martin Luther King Jr Avenue Southeast, W...
# 1    382722   Ward 2  631 P Street Northwest, Washington, District o...
# 2    382723   Ward 8  1110 Oak Drive Southeast, Washington, District...
# 3    382724   Ward 8  1100 Alabama Avenue Southeast, Washington, Dis...
# 4    382725   Ward 7  726 51st Street Northeast, Washington, Distric...
#
#                      PROJECT_NAME STATUS_PUBLIC AGENCY_CALCULATED  \
# 0         STE - Parcels 7, 8, & 9      Pipeline             DMPED
# 1                 7th and P St NW      Pipeline          DMPED OP
# 2  STE - St. Elizabeths Parcel 15      Pipeline             DMPED
# 3                 STE - Parcel 13      Pipeline             DMPED
# 4                  726 51st St NE      Pipeline              DHCD
#
#    TOTAL_AFFORDABLE_UNITS   LATITUDE  LONGITUDE  AFFORDABLE_UNITS_AT_0_30_AMI  \
# 0                   283.0  38.847109 -76.995377                          50.0
# 1                    29.0  38.909868 -77.021195                           3.0
# 2                   151.0  38.846246 -76.990111                          33.0
# 3                   126.0  38.848266 -76.988405                          32.0
# 4                     6.0  38.898990 -76.927789                           0.0
#
#    ...  UNITS_NEWLY_COVENANT_EXISTING  AFFORDABLE_UNITS_PRODUCTION  \
# 0  ...                            0.0                        283.0
# 1  ...                            0.0                         29.0
# 2  ...                            0.0                        151.0
# 3  ...                            0.0                        126.0
# 4  ...                            0.0                          6.0
#
#    UNITS_NET_NEW  UNITS_MARKET UNITS_TOTAL     CONSTRUCTION_END_DATE  \
# 0          283.0          12.0       307.0 2027-12-01 00:00:00+00:00
# 1           29.0         201.0       230.0 2027-12-31 00:00:00+00:00
# 2          151.0         137.0       288.0 2027-06-01 00:00:00+00:00
# 3          126.0         295.0       421.0 2028-01-01 00:00:00+00:00
# 4            6.0          40.0        46.0                       NaT
#
#                  PLANNING_AREA                        geometry  \
# 0  FAR SOUTHEAST AND SOUTHWEST  POINT (326837.595 4301702.915)
# 1               NEAR NORTHWEST  POINT (324751.126 4308717.374)
# 2  FAR SOUTHEAST AND SOUTHWEST   POINT (327284.425 4301590.83)
# 3  FAR SOUTHEAST AND SOUTHWEST  POINT (327445.443 4301818.072)
# 4  FAR NORTHEAST AND SOUTHEAST  POINT (332825.088 4307334.777)
#
#   dist_to_metro_center time_to_metro_center
# 0          7928.957103           686.288552
# 1          1979.256746           169.955236
# 2          8378.579379           731.400404
# 3          8300.334426           724.244857
# 4          9748.687894           801.602413
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Compare to straight line distance

# %%
affordable_housing['straight_dist_to_metro_center'] = affordable_housing.distance(metro_center.geometry.iloc[0])

# %%
affordable_housing.head()
# Out:
#    OBJECTID MAR_WARD                                            ADDRESS  \
# 0    382721   Ward 8  2730 Martin Luther King Jr Avenue Southeast, W...
# 1    382722   Ward 2  631 P Street Northwest, Washington, District o...
# 2    382723   Ward 8  1110 Oak Drive Southeast, Washington, District...
# 3    382724   Ward 8  1100 Alabama Avenue Southeast, Washington, Dis...
# 4    382725   Ward 7  726 51st Street Northeast, Washington, Distric...
#
#                      PROJECT_NAME STATUS_PUBLIC AGENCY_CALCULATED  \
# 0         STE - Parcels 7, 8, & 9      Pipeline             DMPED
# 1                 7th and P St NW      Pipeline          DMPED OP
# 2  STE - St. Elizabeths Parcel 15      Pipeline             DMPED
# 3                 STE - Parcel 13      Pipeline             DMPED
# 4                  726 51st St NE      Pipeline              DHCD
#
#    TOTAL_AFFORDABLE_UNITS   LATITUDE  LONGITUDE  AFFORDABLE_UNITS_AT_0_30_AMI  \
# 0                   283.0  38.847109 -76.995377                          50.0
# 1                    29.0  38.909868 -77.021195                           3.0
# 2                   151.0  38.846246 -76.990111                          33.0
# 3                   126.0  38.848266 -76.988405                          32.0
# 4                     6.0  38.898990 -76.927789                           0.0
#
#    ...  AFFORDABLE_UNITS_PRODUCTION  UNITS_NET_NEW  UNITS_MARKET  UNITS_TOTAL  \
# 0  ...                        283.0          283.0          12.0        307.0
# 1  ...                         29.0           29.0         201.0        230.0
# 2  ...                        151.0          151.0         137.0        288.0
# 3  ...                        126.0          126.0         295.0        421.0
# 4  ...                          6.0            6.0          40.0         46.0
#
#       CONSTRUCTION_END_DATE                PLANNING_AREA  \
# 0 2027-12-01 00:00:00+00:00  FAR SOUTHEAST AND SOUTHWEST
# 1 2027-12-31 00:00:00+00:00               NEAR NORTHWEST
# 2 2027-06-01 00:00:00+00:00  FAR SOUTHEAST AND SOUTHWEST
# 3 2028-01-01 00:00:00+00:00  FAR SOUTHEAST AND SOUTHWEST
# 4                       NaT  FAR NORTHEAST AND SOUTHEAST
#
#                          geometry  dist_to_metro_center time_to_metro_center  \
# 0  POINT (326837.595 4301702.915)           7928.957103           686.288552
# 1  POINT (324751.126 4308717.374)           1979.256746           169.955236
# 2   POINT (327284.425 4301590.83)           8378.579379           731.400404
# 3  POINT (327445.443 4301818.072)           8300.334426           724.244857
# 4  POINT (332825.088 4307334.777)           9748.687894           801.602413
#
#   straight_dist_to_metro_center
# 0                   6564.457184
# 1                   1611.655877
# 2                   6883.749623
# 3                   6777.569350
# 4                   9107.027545
#
# [5 rows x 32 columns]

# %%
(affordable_housing['dist_to_metro_center'] - affordable_housing['straight_dist_to_metro_center']).hist()
# Out:
# <Axes: >

# %%
#KEY TAKEAWAYS
#You can access convenience tools (like OSMNX)
#You can use networks in more abstract ways
#Networks can be a really abstract way to represent how things are connected to one another and you're not confined to streets
