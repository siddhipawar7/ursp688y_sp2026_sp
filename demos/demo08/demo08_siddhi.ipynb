# %% [markdown]
# Urban Data Science & Smart Cities <br>
# URSP688Y Spring 2026<br>
# Instructor: Chester Harvey <br>
# Urban Studies & Planning <br>
# National Center for Smart Growth <br>
# University of Maryland

# %% [markdown]
# # Demo 5 - Accessing and Wrangling Data from the Web
#
# - Loading Data from the Web with APIs
# - Storing Code in Modules

# %% [markdown]
# ## APIs (Application Programming Interfaces)
#
# APIs are an interface for accessing information. At the most general level, nearly all programs that can be accessed with code have an API.
#
# Python functions, for example, are programs with APIs. You access them by calling the function name and defining arguments.
#
# In practice, when people talk about getting data from APIs they are usually talking about web APIs
# - These are usually designed with a software architecture called [REST](https://en.wikipedia.org/wiki/REST).
# - Using a REST API involves making a request to a URL and receiving a response.
# - Often, that response is in a format called [JSON](https://en.wikipedia.org/wiki/JSON), which is structured like nested dictionaries and lists.
#
# Today, we're going to practice retrieving data about cities from web APIs, then wrangling the data they return into a tabular format we can analyze.
#
# Making a request to an API is just another way to get data, similar to downloading it from an open data portal. Why would you bother querying an API instead of just downloading a table?
# - APIs allow programmatic access to data that can be easily scaled, replicated, and documented
# - APIs can allow customization of which data you are accessing
# - JSON allows for much more complex data structures than downloadable tables
# - APIs can be an easy way to access real-time data
# - Can we think of other reasons?

# %% [markdown]
# ### Capital Bikeshare Data — Free, simple, real-time
#
# Some APIs with data about cities are free and simple. The Capital Bikeshare (CABI) system, for example, has an API that reports on the status of bikes in its system in real-time. It's available free as part of CABI's operating agreement with the City of Washington, D.C.
#
# The District Department of Transportation (DDOT) lists APIs for all of the micromobility systems operating in the city on [this webpage](https://ddot.dc.gov/page/dockless-api).
#
# Let's request some data from the CABI systems and see what it looks like.
#
# - What could we do with these data?
# - What are its limitations?

# %% [markdown]
# You may need to install PyYAML, a package for working with YAML-formatted files
#
# `pip install PyYAML`

# %%
# Import package dependencies
import pandas as pd
import requests # for making RESTful API requests
import json # for converting strings in JSON format to python dictionaries and lists
import yaml # for converting yaml-structured text into python dictionaries and lists
import os # for basic operating system functions, like compiling paths

# %%
# Making a "GET" request
response = requests.get('https://gbfs.lyft.com/gbfs/1.1/dca-cabi/en/free_bike_status.json')

# Get JSON content
data = response.json()

# %%
# Preview the data
data
# Out:
# {'data': {'bikes': [{'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.898367167,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '450-3538',
#     'bike_id': '1347d091476ed6e388578d2b355236fb',
#     'lon': -77.043296456},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.887048244,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '813-9735',
#     'bike_id': 'f1ccc4293f38cd39f5d45b2c5538a5ba',
#     'lon': -77.0137012},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.894212723,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '430-1461',
#     'bike_id': 'c069b6741a412b328cb93338e453b974',
#     'lon': -77.094623208},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.908170104,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '689-6666',
#     'bike_id': 'd3f6a36482773b85ab5e4556fcd96d23',
#     'lon': -77.035774469},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.99846983,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '531-7110',
#     'bike_id': '5e12f3fa2875be6ad69077c5c5977311',
#     'lon': -77.040771961},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.908878565,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '339-0820',
#     'bike_id': 'd72f54d25435b2ff226daeb1d30520cf',
#     'lon': -77.001096725},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.880540371,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '439-5356',
#     'bike_id': '0768528d8da612cb1ecacc98940bba07',
#     'lon': -77.025262594},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.845176458,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '784-7460',
#     'bike_id': 'ea178216409fc84c9773b21fd5c9329f',
#     'lon': -77.00797236},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.883964777,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '222-1844',
#     'bike_id': '28f60ed1f30ce1f31a8b03699cd47c82',
#     'lon': -77.100602031},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.942220449,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '492-9212',
#     'bike_id': 'f834db78bd7218b3aee1e4dd33a1fc38',
#     'lon': -77.001872659},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.807651162,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '543-0533',
#     'bike_id': '921831af37d481443a6642b3a76347c6',
#     'lon': -77.07893312},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.865575671,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '798-7084',
#     'bike_id': '8928889ed63e0b60650042b9624586e9',
#     'lon': -77.087473512},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.85569942,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '816-0046',
#     'bike_id': 'da5d59c62fc3b3f5bb2d0724666845b0',
#     'lon': -77.113196015},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.871827483,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '552-6470',
#     'bike_id': '3e42b14781d1822f828f82e209b00d0b',
#     'lon': -77.132653356},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.901970267,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '624-6045',
#     'bike_id': 'b7e5f83cc0f428ef06883a85489ed3d4',
#     'lon': -77.038488507},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.852710724,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '469-8627',
#     'bike_id': 'e927376b9306ebe9c990b0bdeed3830b',
#     'lon': -77.053614855},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.886150002,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '441-6475',
#     'bike_id': 'e16911c7265293ea9bfce72de1aa5751',
#     'lon': -77.165204287},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.883796692,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '801-2163',
#     'bike_id': '1a8e8f6fa41767daf1f86fe5729e9d10',
#     'lon': -77.10018599},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.907897592,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '570-0356',
#     'bike_id': 'd40ad3f1cac09314a50e73b42fc8fc5f',
#     'lon': -77.071662903},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.940657496,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '471-3434',
#     'bike_id': '7ac51cc89803204aa5558386518f20c2',
#     'lon': -77.004225254},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.901322484,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '279-0210',
#     'bike_id': '476eee6c67f74a175e82b315d6b99c09',
#     'lon': -77.043501735},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.905347466,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '475-5344',
#     'bike_id': 'edb60bffb44753e090cdbde43bcdc158',
#     'lon': -77.030595779},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.923990965,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '611-4789',
#     'bike_id': 'b300d475dc2acfbd880b5611b8c684d0',
#     'lon': -77.040863276},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.870517969,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '892-1934',
#     'bike_id': 'b58e729c513bc6e3e1bbd3cf273bde41',
#     'lon': -77.009431243},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.896592379,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '682-7646',
#     'bike_id': '5a5a1ab7069010b4a411c1ba991337e4',
#     'lon': -77.096231818},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.9094491,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '471-0786',
#     'bike_id': '3db698be1f72934a09590c20b406d4f5',
#     'lon': -77.054798484},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.923393488,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '309-6260',
#     'bike_id': 'c985c10d3fad9881086ba2d7f609c2f2',
#     'lon': -76.972284794},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.896586299,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '459-9544',
#     'bike_id': 'd825d0859d9e49007f89019353700af2',
#     'lon': -77.039817929},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.936098933,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '379-0664',
#     'bike_id': 'baf4179b36beddd827d2d8b7eca438bf',
#     'lon': -76.973202109},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.899010897,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '342-5162',
#     'bike_id': '8060a0ce12047cd633978a6c29ec204d',
#     'lon': -77.033413529},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.870634317,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '226-9819',
#     'bike_id': 'd6dcb51714122c805f3d683319ceb055',
#     'lon': -77.150902033},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.895717978,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '581-5022',
#     'bike_id': '843d86ae8d83f8d0a0c27893822837f5',
#     'lon': -77.029772162},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.900976299999996,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '805-0031',
#     'bike_id': '78e9cb41ce48a868d9efe3f3ba697106',
#     'lon': -77.028005838},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.884790659,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '417-7051',
#     'bike_id': 'd9a871ac547a400481b86f43a8987bf2',
#     'lon': -77.005928874},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.896083236,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '594-5514',
#     'bike_id': 'ee2efd06ee630b2c4eb1fadf2a84e5a2',
#     'lon': -77.049583912},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.835095048,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '265-5892',
#     'bike_id': '26d63ac51666410527603b970f662fe1',
#     'lon': -77.114087105},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.84845531,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '714-6566',
#     'bike_id': '51bb18e6bd8e8e83c32732e2596cbb42',
#     'lon': -77.272890449},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.879799843,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '564-9397',
#     'bike_id': '0bcbf09aa1a75a46bd9f6839f2a24063',
#     'lon': -77.037705898},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.906309843,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '546-3518',
#     'bike_id': 'd32f8b6150b1c9821d8c40c47104da9a',
#     'lon': -77.009884119},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.905709386,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '369-0690',
#     'bike_id': 'd1f5e1d944a58b40b8fc8388948d6469',
#     'lon': -77.043557048},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.934238315,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '584-6696',
#     'bike_id': '8e9f294c7c529f0d83d6c10ccdc391e6',
#     'lon': -76.994590998},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.902969837,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '793-4151',
#     'bike_id': '116b4ab40ea3e262ce984e2cb6297909',
#     'lon': -77.060010314},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.894105434,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '457-5494',
#     'bike_id': 'f0f45f9b3f55ef312e69602ef266b0c2',
#     'lon': -77.162148595},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.834972143,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '487-0069',
#     'bike_id': 'eceadd623461909d2a8b075ca52695d3',
#     'lon': -77.064423561},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.87046957,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '563-4365',
#     'bike_id': 'ca33b0156a1efbf11971cecac63f68d6',
#     'lon': -77.009451032},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.953251719,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '525-5138',
#     'bike_id': 'cc5bbf25ab4c0d3a9ccf5109dcfd1740',
#     'lon': -77.085065842},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.898177266,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '454-8459',
#     'bike_id': '33cedb66d51d62486ac672b8cf73389c',
#     'lon': -77.032292604},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.909491658,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '703-9951',
#     'bike_id': '92d361ff7b6d0bb664ee4ea7c5539df6',
#     'lon': -76.988697529},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.961666346,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '798-1368',
#     'bike_id': '3593dda297acb0811e8cc4d871e2ffdb',
#     'lon': -77.086032748},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.901682973,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '590-6904',
#     'bike_id': 'bcdd7b4202121e9007afc7bd7c0efcf5',
#     'lon': -77.044996381},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.904787898,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '281-5140',
#     'bike_id': 'd798a17dc31713c69bf51db11ea403e2',
#     'lon': -77.043611526},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.908794403,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '851-1438',
#     'bike_id': '99ff3c99770cb412efd1e3abb9152003',
#     'lon': -77.148465872},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.881638408,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '608-3927',
#     'bike_id': 'c8fbb421507a07e480e0f5b2af7fdbb0',
#     'lon': -77.027661085},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.898961306,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '660-2148',
#     'bike_id': 'b885e493ef2b5e62f053305bdee55ed9',
#     'lon': -77.033280611},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.898456573,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '467-0931',
#     'bike_id': 'a8e08c624aab6557f955b783e154852d',
#     'lon': -77.033136964},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.918374538,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '642-8262',
#     'bike_id': 'ee9315e8681456577570e49cefed34c1',
#     'lon': -77.063444138},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.900017262,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '882-2694',
#     'bike_id': '61cef99b17d886d55d04255286b48650',
#     'lon': -77.006843209},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.883595346999996,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '293-9114',
#     'bike_id': '3845214fa5f272450f1ccbd1eb28b426',
#     'lon': -77.09932363},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.937120438,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '412-0499',
#     'bike_id': '58b35e89cd232929147f626a62a5eca6',
#     'lon': -77.019123554},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.850537896,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '885-1859',
#     'bike_id': '1fb3f6b0830533f374456331051263be',
#     'lon': -77.051559925},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.856575608,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '812-0347',
#     'bike_id': '8ae6bc8b3dec59695ec30f664f08398b',
#     'lon': -77.10958004},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.89812994,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '654-5495',
#     'bike_id': '0c224ac9e3b1130dc71e4457e8acccf8',
#     'lon': -77.023858309},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.899751663,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '857-2240',
#     'bike_id': 'bfa708552cb75b96eea940de1ef7c9e5',
#     'lon': -77.033778787},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.852247,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '823-0260',
#     'bike_id': 'bbccf55382fba58e1b63abf35f9eaeda',
#     'lon': -76.981463075},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.804215789,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '447-1017',
#     'bike_id': '3053de9302978d1771e19bbc33381075',
#     'lon': -77.080819607},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.907738566,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '517-3646',
#     'bike_id': 'fc6daf8653ff21a6499a8e34fe7cbced',
#     'lon': -77.072500229},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.949969172,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '415-1494',
#     'bike_id': '4e912113ce10403bf4ce30d35f516e6f',
#     'lon': -76.929861069},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.886867046,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '564-7797',
#     'bike_id': 'df3c18628be52c042ecc91bcf34a72e2',
#     'lon': -77.02646184},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.898119688,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '361-4799',
#     'bike_id': '3ca21f3cefbf22421d7f8c4c87bd8fc3',
#     'lon': -77.023860097},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.87668097,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '578-1919',
#     'bike_id': '45d1482bd6e674e935625e892ae5e0dc',
#     'lon': -76.996244669},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.896299839,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '362-7080',
#     'bike_id': 'be7dc65447b968da8c4ea7a047466f5b',
#     'lon': -77.046534657},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.935648084,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '785-7329',
#     'bike_id': '9e7d49d9e72157e5ee4c8346c5fb5902',
#     'lon': -76.974730134},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.884795547,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '639-1007',
#     'bike_id': '764b2810fa26b19b0b83319ab7e9a223',
#     'lon': -77.005987048},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.904842377,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '898-3488',
#     'bike_id': 'ec17dcdc7a279254d2e289f519e04449',
#     'lon': -77.058255911},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.887735248,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '322-2361',
#     'bike_id': 'dab41d13014cd35401a382f9e28b73df',
#     'lon': -77.122280002},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.953821421,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '519-1895',
#     'bike_id': 'dc515d9b4f39d8d2274d891ba6c5527d',
#     'lon': -77.02562952},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.901468396,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '255-5316',
#     'bike_id': '67ddf41558d381be97d702e0c0344689',
#     'lon': -77.040216804},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.941018939,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '623-7028',
#     'bike_id': '59062b834a7989393f11fafdf432fd8a',
#     'lon': -77.056738734},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.917037368,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '368-6276',
#     'bike_id': '25a9153c7dcc083cc9dcc536e531b405',
#     'lon': -77.09562397},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.874288797,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '400-1475',
#     'bike_id': '494876e5f1c42c86341fff3ef34f89c8',
#     'lon': -77.136294127},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.873405099,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '886-0793',
#     'bike_id': '8fe977ca79f066c3cf1377ac9155d730',
#     'lon': -76.991674066},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.875006914,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '875-6819',
#     'bike_id': 'bc31682de6080d7056e85c9f33205e7d',
#     'lon': -77.002562284},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.926533222,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '248-9474',
#     'bike_id': '60f0a5e11a6ff14182f6bc0958771c2b',
#     'lon': -77.014969349},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.898224235,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '422-5983',
#     'bike_id': 'ac98b0a7018eb4e011dbb01f53df0e71',
#     'lon': -77.023847818},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.89705193,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '313-1570',
#     'bike_id': '7d3b17ffa1e769702f157ca46ffc593c',
#     'lon': -77.01166451},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.921468854,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '808-0855',
#     'bike_id': '2ba444ca3cd77eac5c50ff05da929a87',
#     'lon': -76.96892333},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.897845745,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '577-8212',
#     'bike_id': 'ec107d57f25a103a40ae8e425ef5f0c5',
#     'lon': -77.023963451},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.894352674,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '687-4572',
#     'bike_id': 'c40f5e76710a9e17ca34e9bb9e1804f8',
#     'lon': -77.012460351},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.829830408,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '306-5919',
#     'bike_id': 'e065d642fdb1afe0714d0f20c8d8102f',
#     'lon': -77.065042853},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.86872983,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '364-9605',
#     'bike_id': '0e48f1f0597e2d2940e8ec1d1f587f86',
#     'lon': -77.179090858},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.902359962,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '813-8067',
#     'bike_id': 'bc3ce4fd1dc2ab23415046ae22c30dc6',
#     'lon': -77.059155703},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.873100638,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '711-8573',
#     'bike_id': '9585531b5ef26b8cb1f25dcf71045158',
#     'lon': -77.119822502},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.896886468,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '675-2992',
#     'bike_id': 'a1cb981dc4e748dbee2487961cbcc00e',
#     'lon': -77.004938006},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.899433017,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '674-4650',
#     'bike_id': '1cf77e8398764dead1f8096db57787be',
#     'lon': -77.043414354},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.86474967,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '788-8720',
#     'bike_id': 'e44097c0cc831dda4151e0dd37250230',
#     'lon': -77.0881598},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.803089023,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '366-0818',
#     'bike_id': '25299b56cb36f2f427982272ceefd1ad',
#     'lon': -77.04023385},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.894424796,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '733-1424',
#     'bike_id': '75fde1ef2221f500bf9e976e689ee651',
#     'lon': -77.020170689},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.899393559,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '409-3662',
#     'bike_id': '4852bff3d8ceec9200202c549d6af13d',
#     'lon': -77.0151546},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.904063821,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '270-9723',
#     'bike_id': '8dd1a44b749d66e573b7e7a8ab6be67b',
#     'lon': -76.974118233},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.899800777,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '384-3307',
#     'bike_id': 'fb68f1643179114dbed78033e918d2de',
#     'lon': -77.041780114},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.824752092,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '785-7469',
#     'bike_id': 'db4b89e6ee1df1605d73ed88292c4fa9',
#     'lon': -77.085016727},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.883321404,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '567-6622',
#     'bike_id': '3ac46da96b93be3e30760896e959989c',
#     'lon': -77.028157949},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.904185057,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '772-2598',
#     'bike_id': 'aab27204f874ae925f0c7117fc3cf338',
#     'lon': -77.068825006},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.981517315,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '300-7077',
#     'bike_id': '10ea7b6db4007522a37b5ed65bbcd802',
#     'lon': -76.947173357},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.897913456,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '883-6694',
#     'bike_id': '8eb804470eec1b90ce80060866b4d7e2',
#     'lon': -77.023909569},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.984149456,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '248-7676',
#     'bike_id': 'a8fc934155db2819f9cdd97e60c1944f',
#     'lon': -77.013209701},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.897403359,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '637-8590',
#     'bike_id': 'b0d3102fa0bb627f0d1a1f041a5badb0',
#     'lon': -77.007761002},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.953570724,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '871-8330',
#     'bike_id': '05a61b1af90ef24eadbc58ab87566ace',
#     'lon': -77.014273047},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.87114656,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '479-6058',
#     'bike_id': 'd9a42b6834d9e7b77c1770a410f843d9',
#     'lon': -76.953228116},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.92397964,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '420-3774',
#     'bike_id': '0a90a422707736e02c99124ab48d24b3',
#     'lon': -76.955813289},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 39.006857872,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '470-7287',
#     'bike_id': '2ced1621f3ceffd7febb20e6b06dea7b',
#     'lon': -77.040332317},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.898137093,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '794-7187',
#     'bike_id': '158a614e5386b7139b07747372869bf5',
#     'lon': -77.023820758},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.890722752,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '860-3029',
#     'bike_id': '588ac83c19adb0dd8dd0c9759c029657',
#     'lon': -77.121180534},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.905429006,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '334-8778',
#     'bike_id': '88d36aa435b283e3870dc7e8b80f8d79',
#     'lon': -77.044813991},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.929817677,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '858-7222',
#     'bike_id': 'c422c5a3771335197310bc9052d5c23e',
#     'lon': -77.102761626},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.86549747,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '732-2589',
#     'bike_id': '4d90cc4a30b6f657c19e5f2a70ef8787',
#     'lon': -76.990071774},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.902251363,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '321-3816',
#     'bike_id': 'ace73650b7147fb76bd78cb7acd2ed8a',
#     'lon': -77.05906868},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.863641143,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '658-1136',
#     'bike_id': 'cb67430123b17ac86af3c3bce52983da',
#     'lon': -77.085569739},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.902155876,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '471-4069',
#     'bike_id': '38d086f71ddc3b72dc265955e7652e7e',
#     'lon': -77.046805024},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.87047708,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '783-5275',
#     'bike_id': '5fe27f6d54215011ac3e8ee4f03d7284',
#     'lon': -77.009386778},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.898953438,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '851-0844',
#     'bike_id': '7a8dd6ce6fa69a267e8465df290f6b50',
#     'lon': -77.03344214},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.858565688,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '485-9666',
#     'bike_id': '352b8f824358f51919ca6c6d6a6bcded',
#     'lon': -77.023313165},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.803104281,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '837-0017',
#     'bike_id': 'd1031375d89b583879352894af0a168c',
#     'lon': -77.040202975},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.901983261,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '513-8862',
#     'bike_id': 'b16822f6b82bda745ebf832c8689063b',
#     'lon': -77.038370728},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.903428555,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '269-0840',
#     'bike_id': '935de09b5dd900cd454f670239144e00',
#     'lon': -76.928825974},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.902762413,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '206-0549',
#     'bike_id': 'f86f5f079f5dc75f356478d6580ea2ec',
#     'lon': -77.060029149},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.896076441,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '670-5834',
#     'bike_id': 'd132abbee476b532bcbceca3f6f38a3b',
#     'lon': -77.049838781},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.920857787,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '838-6039',
#     'bike_id': '1427df3e52640a175a67b2f09b03088d',
#     'lon': -77.088909149},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.86474061,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '285-5955',
#     'bike_id': 'd188ddc97f6107389c20c34aa6e80178',
#     'lon': -77.078958511},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.991022229,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '307-2147',
#     'bike_id': 'cb66f1393411471be09b036477409ddd',
#     'lon': -77.008429646},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.867147565,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '312-0169',
#     'bike_id': 'acb721e7e280b4ecaf50c5db94830777',
#     'lon': -77.256627679},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
# ...
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '409-3985',
#     'bike_id': '0a561dffb5223a5771a45873290083d2',
#     'lon': -77.058542013},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.900447369,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '737-1255',
#     'bike_id': '391502fd0baff9c130d9ada718689d49',
#     'lon': -77.002072334},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.948110104,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '469-7421',
#     'bike_id': '1b93d11946caee9e3d69bd9a97f42eda',
#     'lon': -76.965325475},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.928742886,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '315-6999',
#     'bike_id': '874a901af1f4d730a2c2da9bd3d6e840',
#     'lon': -77.012497663},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.978172779,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '803-4274',
#     'bike_id': 'd8eeea7b192e51001e1e3c3fa01ef165',
#     'lon': -77.054975629},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.898062348,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '636-0192',
#     'bike_id': 'df3a2584c83046cbd68ca0ceebb19c55',
#     'lon': -77.04285419},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.864197135,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '558-4495',
#     'bike_id': '3f8244497c26148f06f1a63f030bb480',
#     'lon': -77.086051345},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.950962901,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '549-5718',
#     'bike_id': '28bee6ea49bb5c3c5b8dcd949aed26ac',
#     'lon': -77.094466925},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.865492821,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '725-3107',
#     'bike_id': '2d1812c74539821f1c2419a3012f94d4',
#     'lon': -76.95212841},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.91120863,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '518-3348',
#     'bike_id': '2c79343bf7c7bbce009659bfd4f08eb0',
#     'lon': -76.997543931},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.897429216666666,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '368-3794',
#     'bike_id': '218c869eb71a83e484ef9458ea06c062',
#     'lon': -77.009755},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.859799862,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '632-7480',
#     'bike_id': 'c6806f68b762d4d8b5f177bec06bcc3e',
#     'lon': -76.992609143},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.925019383,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '836-4952',
#     'bike_id': '0ce687e07c6c53da498dbd94aa354153',
#     'lon': -77.066481829},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.966361642,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '256-0274',
#     'bike_id': '50d207e0f06f4eef18aaca41bba30a13',
#     'lon': -77.019199491},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.880383968,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '657-6185',
#     'bike_id': '7ec98862f8cad5bb27d8f28c3483bae6',
#     'lon': -77.02507174},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.922896385,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '303-7439',
#     'bike_id': '3fcfdb87397973ee4b78b9db2b991312',
#     'lon': -76.952157974},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.869621873,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '483-0501',
#     'bike_id': '5ea545645413aca78657020fa7668821',
#     'lon': -77.135535836},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.908681631,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '447-4706',
#     'bike_id': '261dc1783ff3ada54ecabdfea6f4916c',
#     'lon': -77.076445341},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.922276378,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '528-2496',
#     'bike_id': 'ab16907f92228638131afd3a2f530862',
#     'lon': -76.989549637},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.999273658,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '750-1349',
#     'bike_id': '4778605398d926fe4a3680e676baac42',
#     'lon': -77.051171184},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.873005271,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '570-3210',
#     'bike_id': '31ed869a5d14805d46e0d7e4ffa83a10',
#     'lon': -76.971030235},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.898244381,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '476-2324',
#     'bike_id': '041d10a5e033f1882810c46752241dcc',
#     'lon': -77.048555255},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.906719446,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '444-6290',
#     'bike_id': 'f8518e94285c5611b51959a52378a0d2',
#     'lon': -77.081478477},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.91065836,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '600-6373',
#     'bike_id': '850cca591d87ded79aeb17a77601f15a',
#     'lon': -76.986732841},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.890734315,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '321-3568',
#     'bike_id': '629a4c51ea104425c70b400906642951',
#     'lon': -77.090970993},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.989628434,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '373-7749',
#     'bike_id': '68719b4f8061ac7f297eae342797294d',
#     'lon': -77.070122242},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.884331226,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '275-8316',
#     'bike_id': 'ec0181f524eddc53ad5351c8b64780bf',
#     'lon': -77.029634356},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.970513225,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '473-8241',
#     'bike_id': 'c9462db354306a4a2d204229c2b17508',
#     'lon': -77.006583452},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.963110566,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '327-2226',
#     'bike_id': '4227bf0ec6e420cf67966fd18f2304e8',
#     'lon': -77.032647133},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.870650887,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '546-4409',
#     'bike_id': '1780b3af072d576de89d0f095d8aed45',
#     'lon': -77.237724304},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.889861703,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '500-9592',
#     'bike_id': '46827633a4a8edcedf1769ce2f1c861d',
#     'lon': -77.003013253},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.934746742,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '552-9375',
#     'bike_id': '778833074ad74595bed56e89055acb58',
#     'lon': -77.09410131},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.85204649,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '720-7079',
#     'bike_id': '9a3e26b3c5337bc9128a24a235d7d25a',
#     'lon': -77.101065755},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.84597671,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '629-6560',
#     'bike_id': '446cf9746e82c46d7c54997ec821e6b3',
#     'lon': -77.077895999},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.968250871,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '629-8673',
#     'bike_id': 'e97661bbfaea2867960de7ecca2376c5',
#     'lon': -77.019787431},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.995563388,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '618-7413',
#     'bike_id': '80d46606ffa3146b574bb53ddd21e430',
#     'lon': -77.054210544},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.890813708,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '359-0742',
#     'bike_id': '1cc6565fff0cc10dd3f17f50234d56a3',
#     'lon': -76.954858422},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.894210696,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '774-8296',
#     'bike_id': '80c3d93f88a3fd574e0056c9a795d808',
#     'lon': -77.012337923},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.908752203,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '518-8768',
#     'bike_id': '3d4914487842cc250c9f11894667bb2c',
#     'lon': -77.07532835},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.907620668,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '456-0868',
#     'bike_id': '0e9df3b2f0b20fed3f635d62cdeec4a4',
#     'lon': -76.989927411},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.868854523,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '539-0232',
#     'bike_id': 'a48215b32690fd5c703bbbf36ed76133',
#     'lon': -77.096940756},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.932575941,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '350-4792',
#     'bike_id': '181a120efd3ed18a5e729cd225011d9a',
#     'lon': -77.065407634},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.948274732,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '727-9193',
#     'bike_id': 'dee8bd5c3d8a92de5a5c49d65ab290c2',
#     'lon': -76.93060863},
#    {'is_disabled': 0,
#     'type': 'electric_bike',
#     'lat': 38.852265358,
#     'is_reserved': 0,
#     'fusion_lat': 0.0,
#     'fusion_lon': 0.0,
#     'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#      'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#     'name': '322-8871',
#     'bike_id': 'e10cc2f7a3a5f5a1a4bf8de744ff4086',
#     'lon': -77.071293235}]},
#  'last_updated': 1774546105,
#  'ttl': 60,
#  'version': '1.1'}

# %%
# Inspect the keys
data.keys()
# Out:
# dict_keys(['data', 'last_updated', 'ttl', 'version'])

# %%
data["last_updated"]
# Out:
# 1774546105

# %%
data['data']['bikes'][:1]
# Out:
# [{'is_disabled': 0,
#   'type': 'electric_bike',
#   'lat': 38.898367167,
#   'is_reserved': 0,
#   'fusion_lat': 0.0,
#   'fusion_lon': 0.0,
#   'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#    'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#   'name': '450-3538',
#   'bike_id': '1347d091476ed6e388578d2b355236fb',
#   'lon': -77.043296456}]

# %%
electric = 0
for bike in data["data"]["bikes"]:
    if bike["type"] == "electric_bike":
        electric += 1
#data["data"]["bikes"][0]

# %%
data['data']['bikes'][1]
# Out:
# {'is_disabled': 0,
#  'type': 'electric_bike',
#  'lat': 38.887048244,
#  'is_reserved': 0,
#  'fusion_lat': 0.0,
#  'fusion_lon': 0.0,
#  'rental_uris': {'android': 'https://dc.lft.to/lastmile_qr_scan',
#   'ios': 'https://dc.lft.to/lastmile_qr_scan'},
#  'name': '813-9735',
#  'bike_id': 'f1ccc4293f38cd39f5d45b2c5538a5ba',
#  'lon': -77.0137012}

# %%
# Make a dataframe out of data for available bikes
df = pd.DataFrame(data['data']['bikes'])

df.head()
# Out:
#    is_disabled           type        lat  is_reserved  fusion_lat  fusion_lon  \
# 0            0  electric_bike  38.898367            0         0.0         0.0
# 1            0  electric_bike  38.887048            0         0.0         0.0
# 2            0  electric_bike  38.894213            0         0.0         0.0
# 3            0  electric_bike  38.908170            0         0.0         0.0
# 4            0  electric_bike  38.998470            0         0.0         0.0
#
#                                          rental_uris      name  \
# 0  {'android': 'https://dc.lft.to/lastmile_qr_sca...  450-3538
# 1  {'android': 'https://dc.lft.to/lastmile_qr_sca...  813-9735
# 2  {'android': 'https://dc.lft.to/lastmile_qr_sca...  430-1461
# 3  {'android': 'https://dc.lft.to/lastmile_qr_sca...  689-6666
# 4  {'android': 'https://dc.lft.to/lastmile_qr_sca...  531-7110
#
#                             bike_id        lon
# 0  1347d091476ed6e388578d2b355236fb -77.043296
# 1  f1ccc4293f38cd39f5d45b2c5538a5ba -77.013701
# 2  c069b6741a412b328cb93338e453b974 -77.094623
# 3  d3f6a36482773b85ab5e4556fcd96d23 -77.035774
# 4  5e12f3fa2875be6ad69077c5c5977311 -77.040772

# %%
df["type"].value_counts()
# Out:
# type
# electric_bike    887
# Name: count, dtype: int64

# %%
# Save the json data for later

def save_json(data, file_name, timestamp=False):
    """Save data as json file
    data: json-compatable data structure (nested dicts and lists)
    file_name: string for file name; DO NOT include file extension (e.g., ".json")
    """
    if timestamp:
        file_name = f'{file_name}_{timestamp}.json'
    else:
        file_name = f'{file_name}.json'
    with open(file_name, 'w') as f:
        json.dump(data, f, indent=4)

save_json(data, 'cabi_data')

# %%
# Make an automated workflow to retrieve data and save it, all at once

def get_and_save_cabi_data():
    """Get current data from the CABI API and save as a timestamped JSON
    """
    # Making a "GET" request
    response = requests.get('https://gbfs.lyft.com/gbfs/1.1/dca-cabi/en/free_bike_status.json')
    # Get JSON content
    data = response.json()
    # Get timestamp from data
    timestamp = data['last_updated']
    # Save to file
    save_json(data, 'cabi_data', timestamp)

# %%
# Run the automated workflow
# Could we do this on a schedule to collect "snapshots" of the state of the CABI system?
get_and_save_cabi_data()

# %% [markdown]
# ### Rentcast — Paid, more complex, updated less frequently
#
# Free APIs like for CABI are becoming less common. (Does this sound familiar in light of today's reading about smart cities as emerging markets?) Many other APIs require that you pay for data, either through a subscription or for request you make. Some have free tiers, but they're usually quite limited.
#
# Several years ago, Zillow provided data about real estate markets through a free API available to the public. You now have to go through a complicated application process to get access to their API, and your use case needs to be aligned with their business model.
#
# An alternative source of real estate data is a company called [Rentcast](https://www.rentcast.io/). They allow anyone to set up an account and purchase data through an API, and it [gets expensive fast](https://www.rentcast.io/api#api-pricing). You get 50 requests free for "development," but after that you pay \\$0.20 per request or \\$74 per month for a subscription to make up to 1,000 requests.
#
# They keep track of who is making requests with an 'API key', which is a long string of characters you include in your request as a 'header'. Because API keys are attached to billing information (i.e., your credit card), they're very sensitive. You ***NEVER*** want to commit your API key to GitHub or share it anywhere else publicly.
#
# It's best practice to store your API key in a separate file—I like to use a format called YAML—that you prevent from being committed by adding it to your respository's `.gitignore` file. This is a list of files that you explicitly tell git not to keep track of.
#
# When you want to use your API key, you load the configs into memory in the Python kernel you're currently working in. When you close or restart the kernel, the computer forgets it.

# %%
# Load personal data from a configs file (API key, local data path)
with open('configs.yaml', 'r') as file:
    CONFIGS = yaml.safe_load(file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 2
#       1 # Load personal data from a configs file (API key, local data path)
# ----> 2 with open('configs.yaml', 'r') as file:
#       3     CONFIGS = yaml.safe_load(file)
#
# File c:\Users\User\miniconda3\envs\688y\Lib\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'configs.yaml'

# %%
# Load eviction data we used last week
df = pd.read_csv('District_Court_of_Maryland_Eviction_Case_Data_MG_PG.csv')

# %%
# Preview columns
df.head(1)
# Out:
#    Unnamed: 0  Event Date                                         Event Type  \
# 0         535  01/03/2023  Warrant of Restitution - Return of Service - E...
#
#   Event Comment      County   Location    Tenant City Tenant State  \
# 0           NaN  Montgomery  Rockville  Silver Spring           MD
#
#    Tenant ZIP Code            Case Type         Case Number Evicted Date  \
# 0          20910.0  Failure to Pay Rent  D-061-LT-22-004107   12/08/2022
#
#    Event Year  Eviction Year
# 0        2023         2022.0

# %%
# def construct_rentcast_json_filename(zipcode):
#     return f'rentcast_{zipcode}.json'

# def get_rentcast_data_for_zipcode(zipcode):
#     # Make GET request to rentcast API
#     url = f'https://api.rentcast.io/v1/markets?zipCode={zipcode}&dataType=All&historyRange=6'
#     headers = {
#         'X-Api-Key': CONFIGS['rentcast_api_key'],
#         'Accept': 'application/json', 
#     }
#     response = requests.get(url, headers=headers)
#     data = response.json()
#     # Save to json
#     file_path = construct_rentcast_json_filename(zipcode)
#     with open(file_path, 'w') as file:
#         json.dump(data, file, indent=4)

# # Get rentcast market data for the 5 zipcodes most represented in the eviction case data
# zipcodes = df['Tenant ZIP Code'].value_counts().head(1).index.astype('Int64')

# for zipcode in zipcodes:
#     get_rentcast_data_for_zipcode(zipcode)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 22
#      19 zipcodes = df['Tenant ZIP Code'].value_counts().head(1).index.astype('Int64')
#      21 for zipcode in zipcodes:
# ---> 22     get_rentcast_data_for_zipcode(zipcode)
#
# Cell In[22], line 8, in get_rentcast_data_for_zipcode(zipcode)
#       4 def get_rentcast_data_for_zipcode(zipcode):
#       5     # Make GET request to rentcast API
#       6     url = f'https://api.rentcast.io/v1/markets?zipCode={zipcode}&dataType=All&historyRange=6'
#       7     headers = {
# ----> 8         'X-Api-Key': CONFIGS['rentcast_api_key'],
#       9         'Accept': 'application/json',
#      10     }
#      11     response = requests.get(url, headers=headers)
#      12     data = response.json()
#
# NameError: name 'CONFIGS' is not defined

# %%
# Preview the data
filename = construct_rentcast_json_filename(zipcode)
with open(filename, 'r') as file_object:
    data_dict = json.load(file_object)

data.keys()

# %%
data['saleData'].keys()

# %%
data['saleData']['dataByPropertyType'][0]

# %% [markdown]
# ## Storing Code in Modules
#
# When writing more complicated code, it can be really helpful to store it in separate files so it doesn't clutter up your notebook. This also makes it easier to use in multiple places. For example, multiple notebooks could access utility functions store in a single custom module.
#
# Can you store functions used to query the APIs above in a separate module, then load and run them in this notebook?

# %%
import demo08

# %%
dir(demo08)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__']
